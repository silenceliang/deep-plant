# %% [markdown]
# # Extract all csv from tensorboard

# %%
import os
import numpy as np
import pandas as pd

from collections import defaultdict
from tensorboard.backend.event_processing.event_accumulator import EventAccumulator
import warnings
warnings.filterwarnings("ignore")

# %%
def tabulate_events(dpath):
    final_out = {}
    for dname in os.listdir(dpath):
        print(f"Converting run {dname}",end="")
        try:
            ea = EventAccumulator(os.path.join(dpath, dname)).Reload()
            tags = ea.Tags()['scalars']
        except:
            continue
        out = {}

        for tag in tags:
            tag_values=[]
            steps=[]

            for event in ea.Scalars(tag):
                tag_values.append(event.value)
                steps.append(event.step)

            out[tag]=pd.DataFrame(data=dict(zip(steps,np.array([tag_values]).transpose())), columns=steps,index=['value'])

        if len(tags)>0:
            try:
                if 'precision' in dname or 'recall' in dname:
                    df= pd.concat(out.values(), keys=out.keys())
                    df.to_csv(os.path.join(dump_path, f'{dname}.csv'))
                    print("- Done")
                
            except Exception as e:
                raise e
        else:
            print('- Not scalers to write')

        final_out[dname] = df

    return final_out

# %%
path = "runs/v1_resNet18_acc79_cat104" # where is the summary
dump_path = 'resNet18_79dump'
os.mkdir(dump_path)
steps = tabulate_events(path)
concate_filename = 'results.csv'
# Out:
# Converting run recall_mallow
# /home/silence/.pyenv/versions/3.7.2/envs/python-3.7.2/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/silence/.pyenv/versions/3.7.2/envs/python-3.7.2/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# ...
